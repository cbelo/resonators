# %%
#run only once!
# %load_ext autoreload
# %autoreload 2
import os
os.chdir(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# %%
import numpy as np
from phidl import LayerSet
from phidl import quickplot as qp
from phidl import Path, CrossSection, Device
import phidl.path as pp
import phidl.geometry as pg
import phidl
import matplotlib.pyplot as plt
# from deprecated.Bertram_Functions.MyPhidlFunctions import *
from Schuster_Resonators.resonator import ChipResonatorsTline, ChipTline, ChipResonatorsTwoTlines
from Schuster_Resonators.approx_Schuster import *
from CPW.cpw import *

# %% [markdown]
# # Kinetic inductances definitions

# %%
# from CPW.cpw import resonance_freq_CPW, impedance_CPW
Lk_12 = 22e-12
FeedlineWidth12 = 80
FeedlineLength12  = 800
FeedlineGap12 = 50

epsilon_r_sGe = [15.3, 16, 15.3, 16]
epsilon_r_uGe = [15.18, 16, 15.51, 16]

thickness_subs_sGe = [22e-9, 25e-9, 2.5e-6, 450e-6]
thickness_subs_uGe = [60e-9, 25e-9, 100e-9, 450e-6]

print('Frequency of the feedline is', resonance_freq_CPW(FeedlineWidth12*1e-6, FeedlineGap12*1e-6, epsilon_r_sGe, thickness_subs_sGe, ind_kin_sq=Lk_12, length_CPW=(FeedlineLength12 )*1e-6)/1e9, 'GHz')
print('Frequency of the feedline is', resonance_freq_CPW(FeedlineWidth12*1e-6, FeedlineGap12*1e-6, epsilon_r_uGe, thickness_subs_uGe, ind_kin_sq=Lk_12, length_CPW=(FeedlineLength12 )*1e-6)/1e9, 'GHz')

print("Impedance of the feedline is", impedance_CPW(FeedlineWidth12*1e-6, FeedlineGap12*1e-6, epsilon_r_sGe, thickness_subs_sGe, ind_kin_sq=Lk_12))
print("Impedance of the feedline is", impedance_CPW(FeedlineWidth12*1e-6, FeedlineGap12*1e-6, epsilon_r_uGe, thickness_subs_uGe, ind_kin_sq=Lk_12))
# Out:
# Frequency of the feedline is 16.130359240081532 GHz
# Frequency of the feedline is 16.130359240081532 GHz
# Impedance of the feedline is 58.31319356889299
# Impedance of the feedline is 58.31319356889299

# %%
SeparationTlineResonator12 = [0]*7 
NumberOfResonators12 = 6

#Resonator parameters
CapacitorHorizontalLength12 = np.ones(NumberOfResonators12)*150
CapacitorVerticalLength12 = np.ones(NumberOfResonators12)*100
CapacitorWidth12 = np.ones(NumberOfResonators12)*5

NumberOfBends12 = np.ones(NumberOfResonators12, dtype=int)*[4,4, 6, 6, 8, 9]
InductorVerticalLength12 = np.ones(NumberOfResonators12)*5
InductorHorizontalLength12 = np.ones(NumberOfResonators12)*[30, 40, 62,  78,  75,  82] 
InductorEndLength12 = np.ones(NumberOfResonators12)*( [70,70,55,55,50,90])
InductorTotalLength12 = InductorVerticalLength12*(NumberOfBends12+4) + InductorEndLength12 +InductorHorizontalLength12*(NumberOfBends12+1)
InductorWidth12 = np.ones(NumberOfResonators12)*0.6
TaperWidth12 = np.ones(NumberOfResonators12)*20

SpacingC012 = np.ones(NumberOfResonators12)*5
# SpacingCc12 = np.ones(NumberOfResonators12)*np.sort(np.linspace(136,0,6))
SpacingCc12 = np.ones(NumberOfResonators12)*[80,80,75,75,70,70]
TaperLength12 = np.ones(NumberOfResonators12)*5
FinalSpacingBondpads12 = 100

FeedlineWidth12 = 80
FeedlineLength12  = 2800
MetalAfterBondpad = 0
FeedlineGap12 = 41
FeedlineTaperLength12 =  100
BondpadWidth12 =  200
BondpadLength12 = 400
BondpadGap12 = BondpadWidth12*(FeedlineGap12/FeedlineWidth12)
ChipSize12 = [FeedlineLength12 + 2*BondpadLength12 + 2*FeedlineTaperLength12 + 2*FinalSpacingBondpads12 + 2*MetalAfterBondpad, 2000]

c, metal, chip12 = ChipResonatorsTline(ChipSize12, NumberOfResonators12, SeparationTlineResonator12,
                        FeedlineWidth12, FeedlineLength12, FeedlineGap12, 
                        FeedlineTaperLength12, BondpadWidth12, BondpadLength12, BondpadGap12,
                        CapacitorHorizontalLength12, CapacitorVerticalLength12, CapacitorWidth12,
                        NumberOfBends12, InductorVerticalLength12, InductorHorizontalLength12, InductorWidth12, InductorEndLength12,
                        TaperWidth12, TaperLength12, SpacingC012, SpacingCc12,
                        FinalSpacingBondpads12, MWO_simulation=False)

qp(chip12)

chip12.write_gds("20260828-uGeRes-22phsq\\gds\\20260828-uGeRes-22phsq.gds")

print(InductorTotalLength12)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# <class 'numpy.ndarray'>
# [260. 310. 539. 651. 785. 975.]

# %%
SeparationTlineResonator12 = [0]*7 
NumberOfResonators12 = 6

#Resonator parameters
CapacitorHorizontalLength12 = np.ones(NumberOfResonators12)*150
CapacitorVerticalLength12 = np.ones(NumberOfResonators12)*100
CapacitorWidth12 = np.ones(NumberOfResonators12)*5

NumberOfBends12 = np.ones(NumberOfResonators12, dtype=int)*[4,4,5,5, 6, 6]
InductorVerticalLength12 = np.ones(NumberOfResonators12)*5
InductorHorizontalLength12 = np.ones(NumberOfResonators12)*[30, 40,48,55, 62,  78] 
InductorEndLength12 = np.ones(NumberOfResonators12)*( [70,70,70,70,55,55])
InductorTotalLength12 = InductorVerticalLength12*(NumberOfBends12+4) + InductorEndLength12 +InductorHorizontalLength12*(NumberOfBends12+1)
InductorWidth12 = np.ones(NumberOfResonators12)*0.6
TaperWidth12 = np.ones(NumberOfResonators12)*20

SpacingC012 = np.ones(NumberOfResonators12)*5
# SpacingCc12 = np.ones(NumberOfResonators12)*np.sort(np.linspace(136,0,6))
SpacingCc12 = np.ones(NumberOfResonators12)*[80,80,75,75,70,70]
TaperLength12 = np.ones(NumberOfResonators12)*5
FinalSpacingBondpads12 = 100

FeedlineWidth12 = 80
FeedlineLength12  = 2800
MetalAfterBondpad = 0
FeedlineGap12 = 41
FeedlineTaperLength12 =  100
BondpadWidth12 =  200
BondpadLength12 = 400
BondpadGap12 = BondpadWidth12*(FeedlineGap12/FeedlineWidth12)
ChipSize12 = [FeedlineLength12 + 2*BondpadLength12 + 2*FeedlineTaperLength12 + 2*FinalSpacingBondpads12 + 2*MetalAfterBondpad, 2000]

c, metal, chip12 = ChipResonatorsTline(ChipSize12, NumberOfResonators12, SeparationTlineResonator12,
                        FeedlineWidth12, FeedlineLength12, FeedlineGap12, 
                        FeedlineTaperLength12, BondpadWidth12, BondpadLength12, BondpadGap12,
                        CapacitorHorizontalLength12, CapacitorVerticalLength12, CapacitorWidth12,
                        NumberOfBends12, InductorVerticalLength12, InductorHorizontalLength12, InductorWidth12, InductorEndLength12,
                        TaperWidth12, TaperLength12, SpacingC012, SpacingCc12,
                        FinalSpacingBondpads12, MWO_simulation=False)

qp(chip12)

chip12.write_gds("20260828-uGeRes-22phsq\\gds\\20260828-uGeRes-22phsq-v2.gds")

print(InductorTotalLength12)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# <class 'numpy.ndarray'>
# [260. 310. 403. 445. 539. 651.]

# %%
SeparationTlineResonator12 = [0]*7 
NumberOfResonators12 = 6

#Resonator parameters
CapacitorHorizontalLength12 = np.ones(NumberOfResonators12)*150
CapacitorVerticalLength12 = np.ones(NumberOfResonators12)*100
CapacitorWidth12 = np.ones(NumberOfResonators12)*5

NumberOfBends12 = np.ones(NumberOfResonators12, dtype=int)*[4,4,5,5, 6, 6]
InductorVerticalLength12 = np.ones(NumberOfResonators12)*5
InductorHorizontalLength12 = np.ones(NumberOfResonators12)*[30, 40,52,60, 62,  78] 
InductorEndLength12 = np.ones(NumberOfResonators12)*( [70,70,70,70,55,55])
InductorTotalLength12 = InductorVerticalLength12*(NumberOfBends12+4) + InductorEndLength12 +InductorHorizontalLength12*(NumberOfBends12+1)
InductorWidth12 = np.ones(NumberOfResonators12)*0.6
TaperWidth12 = np.ones(NumberOfResonators12)*20

SpacingC012 = np.ones(NumberOfResonators12)*5
# SpacingCc12 = np.ones(NumberOfResonators12)*np.sort(np.linspace(136,0,6))
SpacingCc12 = np.ones(NumberOfResonators12)*[80,80,75,75,70,70]
TaperLength12 = np.ones(NumberOfResonators12)*5
FinalSpacingBondpads12 = 100

FeedlineWidth12 = 80
FeedlineLength12  = 2800
MetalAfterBondpad = 0
FeedlineGap12 = 41
FeedlineTaperLength12 =  100
BondpadWidth12 =  200
BondpadLength12 = 400
BondpadGap12 = BondpadWidth12*(FeedlineGap12/FeedlineWidth12)
ChipSize12 = [FeedlineLength12 + 2*BondpadLength12 + 2*FeedlineTaperLength12 + 2*FinalSpacingBondpads12 + 2*MetalAfterBondpad, 2000]

c, metal, chip12 = ChipResonatorsTline(ChipSize12, NumberOfResonators12, SeparationTlineResonator12,
                        FeedlineWidth12, FeedlineLength12, FeedlineGap12, 
                        FeedlineTaperLength12, BondpadWidth12, BondpadLength12, BondpadGap12,
                        CapacitorHorizontalLength12, CapacitorVerticalLength12, CapacitorWidth12,
                        NumberOfBends12, InductorVerticalLength12, InductorHorizontalLength12, InductorWidth12, InductorEndLength12,
                        TaperWidth12, TaperLength12, SpacingC012, SpacingCc12,
                        FinalSpacingBondpads12, MWO_simulation=False)

qp(chip12)

chip12.write_gds("20260828-uGeRes-22phsq\\gds\\20260828-uGeRes-22phsq-v3.gds")

print(InductorTotalLength12)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# <class 'numpy.ndarray'>
# [260. 310. 427. 475. 539. 651.]

# %%
SeparationTlineResonator12 = [0]*7 
NumberOfResonators12 = 6

#Resonator parameters
CapacitorHorizontalLength12 = np.ones(NumberOfResonators12)*150
CapacitorVerticalLength12 = np.ones(NumberOfResonators12)*100
CapacitorWidth12 = np.ones(NumberOfResonators12)*5

NumberOfBends12 = np.ones(NumberOfResonators12, dtype=int)*[4,4,5,5, 6, 6]
InductorVerticalLength12 = np.ones(NumberOfResonators12)*5
InductorHorizontalLength12 = np.ones(NumberOfResonators12)*[30, 40,52,70, 80,  90] 
InductorEndLength12 = np.ones(NumberOfResonators12)*( [70,70,70,70,55,55])
InductorTotalLength12 = InductorVerticalLength12*(NumberOfBends12+4) + InductorEndLength12 +InductorHorizontalLength12*(NumberOfBends12+1)
InductorWidth12 = np.ones(NumberOfResonators12)*0.6
TaperWidth12 = np.ones(NumberOfResonators12)*20

SpacingC012 = np.ones(NumberOfResonators12)*5
# SpacingCc12 = np.ones(NumberOfResonators12)*np.sort(np.linspace(136,0,6))
SpacingCc12 = np.ones(NumberOfResonators12)*[80,80,75,75,70,70]
TaperLength12 = np.ones(NumberOfResonators12)*5
FinalSpacingBondpads12 = 100

FeedlineWidth12 = 80
FeedlineLength12  = 2800
MetalAfterBondpad = 0
FeedlineGap12 = 41
FeedlineTaperLength12 =  100
BondpadWidth12 =  200
BondpadLength12 = 400
BondpadGap12 = BondpadWidth12*(FeedlineGap12/FeedlineWidth12)
ChipSize12 = [FeedlineLength12 + 2*BondpadLength12 + 2*FeedlineTaperLength12 + 2*FinalSpacingBondpads12 + 2*MetalAfterBondpad, 2000]

c, metal, chip12 = ChipResonatorsTline(ChipSize12, NumberOfResonators12, SeparationTlineResonator12,
                        FeedlineWidth12, FeedlineLength12, FeedlineGap12, 
                        FeedlineTaperLength12, BondpadWidth12, BondpadLength12, BondpadGap12,
                        CapacitorHorizontalLength12, CapacitorVerticalLength12, CapacitorWidth12,
                        NumberOfBends12, InductorVerticalLength12, InductorHorizontalLength12, InductorWidth12, InductorEndLength12,
                        TaperWidth12, TaperLength12, SpacingC012, SpacingCc12,
                        FinalSpacingBondpads12, MWO_simulation=False)

qp(chip12)

chip12.write_gds("20260828-uGeRes-22phsq\\gds\\20260828-uGeRes-22phsq-v4.gds")

print(InductorTotalLength12)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# <class 'numpy.ndarray'>
# [260. 310. 427. 535. 665. 735.]

# %%
SeparationTlineResonator12 = [0]*7 
NumberOfResonators12 = 6

#Resonator parameters
CapacitorHorizontalLength12 = np.ones(NumberOfResonators12)*150
CapacitorVerticalLength12 = np.ones(NumberOfResonators12)*100
CapacitorWidth12 = np.ones(NumberOfResonators12)*5

NumberOfBends12 = np.ones(NumberOfResonators12, dtype=int)*[4,4,5,5, 6, 6]
InductorVerticalLength12 = np.ones(NumberOfResonators12)*5
InductorHorizontalLength12 = np.ones(NumberOfResonators12)*[30, 40,52,70, 72,  90] 
InductorEndLength12 = np.ones(NumberOfResonators12)*( [70,70,70,70,55,55])
InductorTotalLength12 = InductorVerticalLength12*(NumberOfBends12+4) + InductorEndLength12 +InductorHorizontalLength12*(NumberOfBends12+1)
InductorWidth12 = np.ones(NumberOfResonators12)*0.6
TaperWidth12 = np.ones(NumberOfResonators12)*20

SpacingC012 = np.ones(NumberOfResonators12)*5
# SpacingCc12 = np.ones(NumberOfResonators12)*np.sort(np.linspace(136,0,6))
SpacingCc12 = np.ones(NumberOfResonators12)*[80,80,75,75,70,70]
TaperLength12 = np.ones(NumberOfResonators12)*5
FinalSpacingBondpads12 = 100

FeedlineWidth12 = 80
FeedlineLength12  = 2800
MetalAfterBondpad = 0
FeedlineGap12 = 41
FeedlineTaperLength12 =  100
BondpadWidth12 =  200
BondpadLength12 = 400
BondpadGap12 = BondpadWidth12*(FeedlineGap12/FeedlineWidth12)
ChipSize12 = [FeedlineLength12 + 2*BondpadLength12 + 2*FeedlineTaperLength12 + 2*FinalSpacingBondpads12 + 2*MetalAfterBondpad, 2000]

c, metal, chip12 = ChipResonatorsTline(ChipSize12, NumberOfResonators12, SeparationTlineResonator12,
                        FeedlineWidth12, FeedlineLength12, FeedlineGap12, 
                        FeedlineTaperLength12, BondpadWidth12, BondpadLength12, BondpadGap12,
                        CapacitorHorizontalLength12, CapacitorVerticalLength12, CapacitorWidth12,
                        NumberOfBends12, InductorVerticalLength12, InductorHorizontalLength12, InductorWidth12, InductorEndLength12,
                        TaperWidth12, TaperLength12, SpacingC012, SpacingCc12,
                        FinalSpacingBondpads12, MWO_simulation=False, cap_sim=True)

qp(chip12)

chip12.write_gds("20260828-uGeRes-22phsq\\gds\\20260828-uGeRes-22phsq-v5-CS.gds")

print(InductorTotalLength12)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# <class 'numpy.ndarray'>
# [260. 310. 427. 535. 609. 735.]

# %%
SeparationTlineResonator12 = [0]*7 
NumberOfResonators12 = 6

#Resonator parameters
CapacitorHorizontalLength12 = np.ones(NumberOfResonators12)*150
CapacitorVerticalLength12 = np.ones(NumberOfResonators12)*100
CapacitorWidth12 = np.ones(NumberOfResonators12)*5

NumberOfBends12 = np.ones(NumberOfResonators12, dtype=int)*[4,4,5,5, 6, 6]
InductorVerticalLength12 = np.ones(NumberOfResonators12)*5
InductorHorizontalLength12 = np.ones(NumberOfResonators12)*[30, 40,52,70, 72,  90] 
InductorEndLength12 = np.ones(NumberOfResonators12)*( [70,70,70,70,55,55])
InductorTotalLength12 = InductorVerticalLength12*(NumberOfBends12+4) + InductorEndLength12 +InductorHorizontalLength12*(NumberOfBends12+1)
InductorWidth12 = np.ones(NumberOfResonators12)*0.6
TaperWidth12 = np.ones(NumberOfResonators12)*20

SpacingC012 = np.ones(NumberOfResonators12)*5
# SpacingCc12 = np.ones(NumberOfResonators12)*np.sort(np.linspace(136,0,6))
SpacingCc12 = np.ones(NumberOfResonators12)*[80,80,75,75,70,70]
TaperLength12 = np.ones(NumberOfResonators12)*5
FinalSpacingBondpads12 = 100

FeedlineWidth12 = 80
FeedlineLength12  = 2800
MetalAfterBondpad = 0
FeedlineGap12 = 41
FeedlineTaperLength12 =  100
BondpadWidth12 =  200
BondpadLength12 = 400
BondpadGap12 = BondpadWidth12*(FeedlineGap12/FeedlineWidth12)
ChipSize12 = [FeedlineLength12 + 2*BondpadLength12 + 2*FeedlineTaperLength12 + 2*FinalSpacingBondpads12 + 2*MetalAfterBondpad, 2000]

c, metal, chip12 = ChipResonatorsTline(ChipSize12, NumberOfResonators12, SeparationTlineResonator12,
                        FeedlineWidth12, FeedlineLength12, FeedlineGap12, 
                        FeedlineTaperLength12, BondpadWidth12, BondpadLength12, BondpadGap12,
                        CapacitorHorizontalLength12, CapacitorVerticalLength12, CapacitorWidth12,
                        NumberOfBends12, InductorVerticalLength12, InductorHorizontalLength12, InductorWidth12, InductorEndLength12,
                        TaperWidth12, TaperLength12, SpacingC012, SpacingCc12,
                        FinalSpacingBondpads12, MWO_simulation=False, cap_sim=False)

qp(chip12)

chip12.write_gds("20260828-uGeRes-22phsq\\gds\\20260828-uGeRes-22phsq-final.gds")

print(InductorTotalLength12)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [260. 310. 427. 535. 609. 735.]
