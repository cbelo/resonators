# %%
# ----------------------------------------------
# Script Recorded by Ansys Electronics Desktop Version 2024.2.0
# 14:38:32  Feb 06, 2025
# ----------------------------------------------
import ScriptEnv
ScriptEnv.Initialize("Ansoft.ElectronicsDesktop")
oDesktop.RestoreWindow()
oProject = oDesktop.NewProject()
oProject.InsertDesign("Q3D Extractor", "Q3DDesign1", "", "")
oDesign = oProject.SetActiveDesign("Q3DDesign1")
oDesign.RenameDesignInstance("Q3DDesign1", "scripttest")
oEditor = oDesign.SetActiveEditor("3D Modeler")
oEditor.ImportGDSII(
	[
		"NAME:options",
		"FileName:="		, "C:/Users/localadmin/Documents/Ansoft/julian_gds/tooth_testchip_zerovl_precision10_extraDX_extraDiaglen.gds",
		"FlattenHierarchy:="	, True,
		[
			"NAME:LayerMap",
			[
				"NAME:LayerMapInfo",
				"LayerNum:="		, 0,
				"DestLayer:="		, "Signal0",
				"layer_type:="		, "signal"
			],
			[
				"NAME:LayerMapInfo",
				"LayerNum:="		, 4,
				"DestLayer:="		, "Signal4",
				"layer_type:="		, "signal"
			]
		],
		"OrderMap:="		, [			"entry:="		, [				"order:="		, 0,				"layer:="		, "Signal0"],			"entry:="		, [				"order:="		, 1,				"layer:="		, "Signal4"]]
	])

# oDesign = oProject.SetActiveDesign("scripttest")
# oEditor = oDesign.SetActiveEditor("3D Modeler")
oEditor.CreateBox(
	[
		"NAME:BoxParameters",
		"XPosition:="		, "-2.5125mm",
		"YPosition:="		, "-1.5mm",
		"ZPosition:="		, "0mm",
		"XSize:="		, "5.025mm",
		"YSize:="		, "3mm",
		"ZSize:="		, "-0.6mm"
	], 
	[
		"NAME:Attributes",
		"Name:="		, "Box1",
		"Flags:="		, "",
		"Color:="		, "(143 175 143)",
		"Transparency:="	, 0,
		"PartCoordinateSystem:=", "Global",
		"UDMId:="		, "",
		"MaterialValue:="	, "\"copper\"",
		"SurfaceMaterialValue:=", "\"\"",
		"SolveInside:="		, False,
		"ShellElement:="	, False,
		"ShellElementThickness:=", "0mm",
		"ReferenceTemperature:=", "20cel",
		"IsMaterialEditable:="	, True,
		"IsSurfaceMaterialEditable:=", True,
		"UseMaterialAppearance:=", False,
		"IsLightweight:="	, False
	])
oEditor = oDesign.SetActiveEditor("3D Modeler")
oEditor.AssignMaterial(
	[
		"NAME:Selections",
		"AllowRegionDependentPartSelectionForPMLCreation:=", True,
		"AllowRegionSelectionForPMLCreation:=", True,
		"Selections:="		, "Box1"
	], 
	[
		"NAME:Attributes",
		"MaterialValue:="	, "\"silicon\"",
		"SolveInside:="		, False,
		"ShellElement:="	, False,
		"ShellElementThickness:=", "nan ",
		"ReferenceTemperature:=", "nan ",
		"IsMaterialEditable:="	, True,
		"IsSurfaceMaterialEditable:=", True,
		"UseMaterialAppearance:=", False,
		"IsLightweight:="	, False
	])
oModule = oDesign.GetModule("BoundarySetup")
oModule.AssignThinConductor(
	[
		"NAME:ThinCond1",
		"Objects:="		, ["Signal0_1","Signal0_2","Signal0_3","Signal0_4","Signal4_5","Signal4_6","Signal4_7","Signal4_8","Signal4_9","Signal4_10","Signal4_11","Signal4_12","Signal4_13","Signal4_14","Signal4_15","Signal4_16","Signal4_17","Signal4_18","Signal4_19","Signal4_20","Signal4_21","Signal4_22","Signal4_23","Signal4_24","Signal4_25","Signal4_26","Signal4_27","Signal4_28"],
		"Material:="		, "Copper",
		"Thickness:="		, "100nm"
	])
oModule.AutoIdentifyNets()
oModule = oDesign.GetModule("AnalysisSetup")
oModule.InsertSetup("Matrix", 
	[
		"NAME:Setup1",
		"AdaptiveFreq:="	, "5GHz",
		"SaveFields:="		, False,
		"Enabled:="		, True,
		[
			"NAME:Cap",
			"MaxPass:="		, 10,
			"MinPass:="		, 1,
			"MinConvPass:="		, 1,
			"PerError:="		, 1,
			"PerRefine:="		, 30,
			"AutoIncreaseAccuracy:=", True,
			"AccuracyLevel:="	, "High",
			"Solver Type:="		, "Iterative"
		],
		"EnableTransitionRegionSolve:=", False,
		"ErrorValue:="		, "0.1"
	])
oProject.Save()
oDesign.Analyze("Setup1")
oModule = oDesign.GetModule("BoundarySetup")
oModule.RenameBoundary("Signal4_5", "res2")
oModule.RenameBoundary("Signal0_1", "gnd")
oModule.RenameBoundary("Signal4_9", "res4")
oModule.RenameBoundary("Signal4_21", "res3")
oModule = oDesign.GetModule("ReportSetup")
oModule.CreateReport("C Matrix Table 1", "Matrix", "Data Table", "Setup1 : LastAdaptive", 
	[
		"Context:="		, "Original"
	], 
	[
		"Freq:="		, ["All"],
		"extent_x_pos:="	, ["Nominal"],
		"extent_y_pos:="	, ["Nominal"],
		"extent_x_size:="	, ["Nominal"],
		"extent_y_size:="	, ["Nominal"],
		"Signal1_lower_elevation:=", ["Nominal"],
		"Signal2_lower_elevation:=", ["Nominal"],
		"extent_x_pos_1:="	, ["Nominal"],
		"extent_y_pos_1:="	, ["Nominal"],
		"extent_x_size_1:="	, ["Nominal"],
		"extent_y_size_1:="	, ["Nominal"],
		"Signal1_lower_elevation_1:=", ["Nominal"],
		"Signal2_lower_elevation_1:=", ["Nominal"],
		"extent_x_pos_2:="	, ["Nominal"],
		"extent_y_pos_2:="	, ["Nominal"],
		"extent_x_size_2:="	, ["Nominal"],
		"extent_y_size_2:="	, ["Nominal"],
		"Signal0_lower_elevation:=", ["Nominal"],
		"Signal4_lower_elevation:=", ["Nominal"]
	], 
	[
		"X Component:="		, "Freq",
		"Y Component:="		, ["C(res2,gnd)","C(res3,gnd)","C(res4,gnd)","C(res3,res2)","C(res4,res2)","C(res4,res3)"]
	])

# %%
# Save the script to a file
script_content = """
import ScriptEnv
ScriptEnv.Initialize("Ansoft.ElectronicsDesktop")
oDesktop.RestoreWindow()
oProject = oDesktop.NewProject()
oProject.InsertDesign("Q3D Extractor", "Q3DDesign1", "", "")
oDesign = oProject.SetActiveDesign("Q3DDesign1")
oDesign.RenameDesignInstance("Q3DDesign1", "scripttest")
oEditor = oDesign.SetActiveEditor("3D Modeler")
oEditor.ImportGDSII(
    [
        "NAME:options",
        "FileName:="        , "C:/Users/localadmin/Documents/Ansoft/julian_gds/tooth_testchip_zerovl_precision10_extraDX_extraDiaglen.gds",
        "FlattenHierarchy:="    , True,
        [
            "NAME:LayerMap",
            [
                "NAME:LayerMapInfo",
                "LayerNum:="        , 0,
                "DestLayer:="        , "Signal0",
                "layer_type:="        , "signal"
            ],
            [
                "NAME:LayerMapInfo",
                "LayerNum:="        , 4,
                "DestLayer:="        , "Signal4",
                "layer_type:="        , "signal"
            ]
        ],
        "OrderMap:="        , [            "entry:="        , [                "order:="        , 0,                "layer:="        , "Signal0"],            "entry:="        , [                "order:="        , 1,                "layer:="        , "Signal4"]]
    ])

# oDesign = oProject.SetActiveDesign("scripttest")
# oEditor = oDesign.SetActiveEditor("3D Modeler")
oEditor.CreateBox(
    [
        "NAME:BoxParameters",
        "XPosition:="        , "-2.5125mm",
        "YPosition:="        , "-1.5mm",
        "ZPosition:="        , "0mm",
        "XSize:="        , "5.025mm",
        "YSize:="        , "3mm",
        "ZSize:="        , "-0.6mm"
    ], 
    [
        "NAME:Attributes",
        "Name:="        , "Box1",
        "Flags:="        , "",
        "Color:="        , "(143 175 143)",
        "Transparency:="    , 0,
        "PartCoordinateSystem:=", "Global",
        "UDMId:="        , "",
        "MaterialValue:="    , "\\"copper\\"",
        "SurfaceMaterialValue:=", "\\"\\"",
        "SolveInside:="        , False,
        "ShellElement:="    , False,
        "ShellElementThickness:=", "0mm",
        "ReferenceTemperature:=", "20cel",
        "IsMaterialEditable:="    , True,
        "IsSurfaceMaterialEditable:=", True,
        "UseMaterialAppearance:=", False,
        "IsLightweight:="    , False
    ])
oEditor = oDesign.SetActiveEditor("3D Modeler")
oEditor.AssignMaterial(
    [
        "NAME:Selections",
        "AllowRegionDependentPartSelectionForPMLCreation:=", True,
        "AllowRegionSelectionForPMLCreation:=", True,
        "Selections:="        , "Box1"
    ], 
    [
        "NAME:Attributes",
        "MaterialValue:="    , "\\"silicon\\"",
        "SolveInside:="        , False,
        "ShellElement:="    , False,
        "ShellElementThickness:=", "nan ",
        "ReferenceTemperature:=", "nan ",
        "IsMaterialEditable:="    , True,
        "IsSurfaceMaterialEditable:=", True,
        "UseMaterialAppearance:=", False,
        "IsLightweight:="    , False
    ])
oModule = oDesign.GetModule("BoundarySetup")
oModule.AssignThinConductor(
    [
        "NAME:ThinCond1",
        "Objects:="        , ["Signal0_1","Signal0_2","Signal0_3","Signal0_4","Signal4_5","Signal4_6","Signal4_7","Signal4_8","Signal4_9","Signal4_10","Signal4_11","Signal4_12","Signal4_13","Signal4_14","Signal4_15","Signal4_16","Signal4_17","Signal4_18","Signal4_19","Signal4_20","Signal4_21","Signal4_22","Signal4_23","Signal4_24","Signal4_25","Signal4_26","Signal4_27","Signal4_28"],
        "Material:="        , "Copper",
        "Thickness:="        , "100nm"
    ])
oModule.AutoIdentifyNets()
oModule = oDesign.GetModule("AnalysisSetup")
oModule.InsertSetup("Matrix", 
    [
        "NAME:Setup1",
        "AdaptiveFreq:="    , "5GHz",
        "SaveFields:="        , False,
        "Enabled:="        , True,
        [
            "NAME:Cap",
            "MaxPass:="        , 10,
            "MinPass:="        , 1,
            "MinConvPass:="        , 1,
            "PerError:="        , 1,
            "PerRefine:="        , 30,
            "AutoIncreaseAccuracy:=", True,
            "AccuracyLevel:="    , "High",
            "Solver Type:="        , "Iterative"
        ],
        "EnableTransitionRegionSolve:=", False,
        "ErrorValue:="        , "0.1"
    ])
oProject.Save()
oDesign.Analyze("Setup1")
oModule = oDesign.GetModule("BoundarySetup")
oModule.RenameBoundary("Signal4_5", "res2")
oModule.RenameBoundary("Signal0_1", "gnd")
oModule.RenameBoundary("Signal4_9", "res4")
oModule.RenameBoundary("Signal4_21", "res3")
oModule = oDesign.GetModule("ReportSetup")
oModule.CreateReport("C Matrix Table 1", "Matrix", "Data Table", "Setup1 : LastAdaptive", 
    [
        "Context:="        , "Original"
    ], 
    [
        "Freq:="        , ["All"],
        "extent_x_pos:="    , ["Nominal"],
        "extent_y_pos:="    , ["Nominal"],
        "extent_x_size:="    , ["Nominal"],
        "extent_y_size:="    , ["Nominal"],
        "Signal1_lower_elevation:=", ["Nominal"],
        "Signal2_lower_elevation:=", ["Nominal"],
        "extent_x_pos_1:="    , ["Nominal"],
        "extent_y_pos_1:="    , ["Nominal"],
        "extent_x_size_1:="    , ["Nominal"],
        "extent_y_size_1:="    , ["Nominal"],
        "Signal1_lower_elevation_1:=", ["Nominal"],
        "Signal2_lower_elevation_1:=", ["Nominal"],
        "extent_x_pos_2:="    , ["Nominal"],
        "extent_y_pos_2:="    , ["Nominal"],
        "extent_x_size_2:="    , ["Nominal"],
        "extent_y_size_2:="    , ["Nominal"],
        "Signal0_lower_elevation:=", ["Nominal"],
        "Signal4_lower_elevation:=", ["Nominal"]
    ], 
    [
        "X Component:="        , "Freq",
        "Y Component:="        , ["C(res2,gnd)","C(res3,gnd)","C(res4,gnd)","C(res3,res2)","C(res4,res2)","C(res4,res3)"]
    ])
"""

with open("ansys_script.py", "w") as file:
    file.write(script_content)

# Run the script in Ansys Electronics Desktop
import os
os.system("ansysedt.exe -runscript ansys_script.py")
# Out:
# 1

# %%
import os

# Path to the Ansys Electronics Desktop executable
ansys_executable_path = "C:/Program Files/AnsysEM/AnsysEM21.2/Win64/ansysedt.exe"

# Open Ansys Electronics Desktop
os.system(f'"{ansys_executable_path}"')
# Out:
# 1

# %%
# !pip install -U pyaedt
# Out:
# Requirement already satisfied: pyaedt in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (0.13.1)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyansys 2025.1.2 requires pyaedt==0.13.1, but you have pyaedt 0.13.3 which is incompatible.
# Collecting pyaedt
#   Downloading pyaedt-0.13.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: fpdf2 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (2.8.2)
# Requirement already satisfied: jsonschema in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (4.23.0)
# Requirement already satisfied: psutil in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (6.1.1)
# Requirement already satisfied: pyedb>=0.24.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (0.34.3)
# Requirement already satisfied: tomli-w in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (1.2.0)
# Requirement already satisfied: rpyc<6.1,>=6.0.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (6.0.1)
# Requirement already satisfied: pyyaml in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (6.0.2)
# Requirement already satisfied: defusedxml<8.0,>=0.7 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (0.7.1)
# Requirement already satisfied: attrs<24.3.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (24.2.0)
# Requirement already satisfied: referencing<0.36.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyaedt) (0.35.1)
# Requirement already satisfied: pywin32>=303 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (305.1)
# Requirement already satisfied: ansys-pythonnet>=3.1.0rc4 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (3.1.0rc6)
# Requirement already satisfied: numpy<3,>=1.20.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (2.0.1)
# Requirement already satisfied: pandas<2.3,>=1.1.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (2.2.2)
# Requirement already satisfied: pydantic<2.10,>=2.6.4 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (2.9.2)
# Requirement already satisfied: Rtree>=1.2.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (1.3.0)
# Requirement already satisfied: toml==0.10.2 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (0.10.2)
# Requirement already satisfied: scikit-rf in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pyedb>=0.24.0->pyaedt) (1.5.0)
# Requirement already satisfied: rpds-py>=0.7.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from referencing<0.36.0->pyaedt) (0.22.3)
# Requirement already satisfied: plumbum in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from rpyc<6.1,>=6.0.0->pyaedt) (1.9.0)
# Requirement already satisfied: Pillow!=9.2.*,>=6.2.2 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from fpdf2->pyaedt) (10.4.0)
# Requirement already satisfied: fonttools>=4.34.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from fpdf2->pyaedt) (4.53.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from jsonschema->pyaedt) (2024.10.1)
# Requirement already satisfied: clr_loader<0.3.0,>=0.2.5 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from ansys-pythonnet>=3.1.0rc4->pyedb>=0.24.0->pyaedt) (0.2.7.post0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pandas<2.3,>=1.1.0->pyedb>=0.24.0->pyaedt) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pandas<2.3,>=1.1.0->pyedb>=0.24.0->pyaedt) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pandas<2.3,>=1.1.0->pyedb>=0.24.0->pyaedt) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pydantic<2.10,>=2.6.4->pyedb>=0.24.0->pyaedt) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pydantic<2.10,>=2.6.4->pyedb>=0.24.0->pyaedt) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from pydantic<2.10,>=2.6.4->pyedb>=0.24.0->pyaedt) (4.12.2)
# Requirement already satisfied: scipy>=1.7 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from scikit-rf->pyedb>=0.24.0->pyaedt) (1.14.1)
# Requirement already satisfied: cffi>=1.17 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from clr_loader<0.3.0,>=0.2.5->ansys-pythonnet>=3.1.0rc4->pyedb>=0.24.0->pyaedt) (1.17.1)
# Requirement already satisfied: six>=1.5 in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=1.1.0->pyedb>=0.24.0->pyaedt) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\localadmin\anaconda3\envs\resonators\lib\site-packages (from cffi>=1.17->clr_loader<0.3.0,>=0.2.5->ansys-pythonnet>=3.1.0rc4->pyedb>=0.24.0->pyaedt) (2.22)
# Downloading pyaedt-0.13.3-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 68.1 MB/s eta 0:00:00
# Installing collected packages: pyaedt
#   Attempting uninstall: pyaedt
#     Found existing installation: pyaedt 0.13.1
#     Uninstalling pyaedt-0.13.1:
#       Successfully uninstalled pyaedt-0.13.1
# Successfully installed pyaedt-0.13.3

# %%
from ansys.EDT.core import launch_EDT

# Launch ANSYS
mapdl = launch_EDT()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from ansys.mapdl.core import launch_EDT
#       3 # Launch ANSYS
#       4 mapdl = launch_EDT()
#
# ImportError: cannot import name 'launch_EDT' from 'ansys.mapdl.core' (c:\Users\localadmin\anaconda3\envs\resonators\Lib\site-packages\ansys\mapdl\core\__init__.py)

# %%
from pyaedt import Desktop

# Launch ANSYS Electronics Desktop (AEDT) with the desired version
desktop = Desktop(specified_version="2023R2", new_desktop=True)  # Update with your version
# Out:
# PyAEDT INFO: Python version 3.12.5 | packaged by conda-forge | (main, Aug  8 2024, 18:24:51) [MSC v.1940 64 bit (AMD64)]
# PyAEDT INFO: PyAEDT version 0.13.1.
# PyAEDT INFO: Initializing new Desktop session.
# PyAEDT WARNING: Argument `specified_version` is deprecated for method `__init__`; use `version` instead.
# PyAEDT INFO: Log on console is enabled.
# PyAEDT INFO: Log on file C:\Users\LOCALA~1\AppData\Local\Temp\pyaedt_localadmin_3417a80b-435e-4cc5-9279-7e8f6233ff3b.log is enabled.
# PyAEDT INFO: Log on AEDT is enabled.
# PyAEDT INFO: Debug logger is disabled. PyAEDT methods will not be logged.
# PyAEDT ERROR: **************************************************************
# PyAEDT ERROR:   File "<frozen runpy>", line 198, in _run_module_as_main
# PyAEDT ERROR:   File "<frozen runpy>", line 88, in _run_code
# PyAEDT ERROR:   File "c:\Users\localadmin\anaconda3\envs\resonators\Lib\asyncio\base_events.py", line 641, in run_forever
# PyAEDT ERROR:     self._run_once()
# PyAEDT ERROR:   File "c:\Users\localadmin\anaconda3\envs\resonators\Lib\asyncio\base_events.py", line 1986, in _run_once
# PyAEDT ERROR:     handle._run()
# PyAEDT ERROR:   File "c:\Users\localadmin\anaconda3\envs\resonators\Lib\asyncio\events.py", line 88, in _run
# PyAEDT ERROR:     self._context.run(self._callback, *self._args)
# PyAEDT ERROR:   File "C:\Users\localadmin\AppData\Local\Temp\ipykernel_30464\1758010099.py", line 4, in <module>
# PyAEDT ERROR:     desktop = Desktop(specified_version="2023R2", new_desktop=True)  # Update with your version
# PyAEDT ERROR: Could not convert string to float: '2023r2' on __init__
# PyAEDT ERROR: Method arguments:
# PyAEDT ERROR:     version = 2023R2
# PyAEDT ERROR:     new_desktop = True
# PyAEDT ERROR: **************************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 from pyaedt import Desktop
#       3 # Launch ANSYS Electronics Desktop (AEDT) with the desired version
# ----> 4 desktop = Desktop(specified_version="2023R2", new_desktop=True)  # Update with your version
#
# TypeError: __init__() should return None, not 'bool'
